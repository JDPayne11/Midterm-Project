# %% [markdown]
# # Data exploration

# %% [markdown]
# To get my data from postgresql into python I saved my data in batches of 50000 from December 1st 2018 to April 31st 2019.
# I then imported my data into 10 dataframes and checked their shape to ensure consistency.

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('csv_file/2018-12-01 to 2018-12-16.csv')
df2 = pd.read_csv('csv_file/2018-12-17 to 2018-12-31.csv')
df3 = pd.read_csv('csv_file/2019-01-01 to 2019-01-15.csv')
df4 = pd.read_csv('csv_file/2019-01-16 to 2019-01-31.csv')
df5 = pd.read_csv('csv_file/2019-02-01 to 2019-02-15.csv')
df6 = pd.read_csv('csv_file/2019-02-16 to 2019-02-28.csv')
df7 = pd.read_csv('csv_file/2019-03-01 to 2019-03-15.csv')
df8 = pd.read_csv('csv_file/2019-03-16 to 2019-03-31.csv')
df9 = pd.read_csv('csv_file/2019-04-01 to 2019-04-16.csv')
df10 = pd.read_csv('csv_file/2019-04-17 to 2019-04-31.csv')
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]
df = pd.concat(frames)
#Checking shape of each dataframe
for value in frames:
    print(value.shape)
# Out:
# C:\Users\JDPayne\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (50000, 42)
# (50000, 42)
# (50000, 42)
# (50000, 42)
# (50000, 42)
# (50000, 42)
# (50000, 42)
# (50000, 42)
# (50000, 42)
# (50000, 42)

# %%
# Checking shape of final dataframe and printing the head
print(df.shape)
df.head()
# Out:
# (500000, 32)
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-12-02                 UA       UA_CODESHARE          UA
# 1  2018-12-05                 WN                 WN          WN
# 2  2018-12-05                 WN                 WN          WN
# 3  2018-12-01                 AA       AA_CODESHARE          AA
# 4  2018-12-01                 F9                 F9          F9
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                4052                EV   N29906               4052
# 1                2382                WN   N962WN               2382
# 2                1980                WN   N241WN               1980
# 3                4541                YX   N443YX               4541
# 4                1869                F9   N305FR               1869
#
#    origin_airport_id origin  ... arr_time  arr_delay cancelled diverted  dup  \
# 0              13342    MKE  ...      NaN        NaN         1        0    N
# 1              14771    SFO  ...      NaN        NaN         1        0    N
# 2              14893    SMF  ...      NaN        NaN         1        0    N
# 3              14100    PHL  ...      NaN        NaN         1        0    N
# 4              11193    CVG  ...      NaN        NaN         1        0    N
#
#    crs_elapsed_time  actual_elapsed_time  air_time  flights  distance
# 0               142                  NaN       NaN        1       725
# 1                90                  NaN       NaN        1       337
# 2                85                  NaN       NaN        1       373
# 3               201                  NaN       NaN        1      1088
# 4               267                  NaN       NaN        1      1569
#
# [5 rows x 32 columns]

# %% [markdown]
# # Dealing with Missing Values and Duplicates

# %%
# Droping columns that have mostly null values
drop_columns = ['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay', 'first_dep_time', 'total_add_gtime', 'longest_add_gtime', 'no_name', 'cancellation_code']
df = df.drop(drop_columns, axis = 1)

#Checking for duplicates
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24108/1712683393.py in <module>
#       1 # Droping columns that have mostly null values
#       2 drop_columns = ['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay', 'first_dep_time', 'total_add_gtime', 'longest_add_gtime', 'no_name', 'cancellation_code']
# ----> 3 df = df.drop(drop_columns, axis = 1)
#       4
#       5 #Checking for duplicates
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['carrier_delay' 'weather_delay' 'nas_delay' 'security_delay'\n 'late_aircraft_delay' 'first_dep_time' 'total_add_gtime'\n 'longest_add_gtime' 'no_name' 'cancellation_code'] not found in axis"

# %%
# Calculating null value ratios
percent = df.isnull().sum().sort_values(ascending=False)/500000
total = df.isnull().sum().sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis = 1, keys = ['Total', 'Percent'])
missing_data.head(12)
# Out:
#                      Total   Percent
# air_time              8639  0.017278
# actual_elapsed_time   8639  0.017278
# arr_delay             8639  0.017278
# wheels_on             7892  0.015784
# taxi_in               7892  0.015784
# arr_time              7892  0.015784
# wheels_off            7557  0.015114
# taxi_out              7557  0.015114
# dep_delay             7440  0.014880
# dep_time              7439  0.014878
# tail_num              1464  0.002928
# cancelled                0  0.000000

# %%
# Extracing columns with missing values
missing_columns = missing_data[missing_data['Total'] > 0].index.tolist()
df.dtypes[missing_columns]
# Out:
# air_time               float64
# actual_elapsed_time    float64
# arr_delay              float64
# wheels_on              float64
# taxi_in                float64
# arr_time               float64
# wheels_off             float64
# taxi_out               float64
# dep_delay              float64
# dep_time               float64
# tail_num                object
# dtype: object

# %%
# Extracing columns with float missing values
#numeric_missing_columns = df.dtypes[missing_columns][df.dtypes[missing_columns] == 'float'].index.tolist()

# Creating a new column to keep track of which rows had missing values before replacement
# for value in numeric_missing_columns:
#     df[value + "_missing"] = 0
#     df.loc[df[value].isnull(), value + "_missing"] = 1

# %%
# Filling missing values
df['air_time'] = df['air_time'].fillna(df['air_time'].mean())
df['actual_elapsed_time'] = df['actual_elapsed_time'].fillna(df['actual_elapsed_time'].mean())
df['arr_delay'] = df['arr_delay'].fillna(0)
df['taxi_in'] = df['taxi_in'].fillna(df['taxi_in'].mean())
df['taxi_out'] = df['taxi_out'].fillna(df['taxi_out'].mean())
df['dep_delay'] = df['dep_delay'].fillna(0)

# I will be dropping rows with null values in these columns because they're listed as timed (hhmm). Taking the mean or guessing what time a flight departed/landed doesn't seem helpful especially because most rows without
# a dep_time also had a missing arr_time
DropNull = ['wheels_on', 'arr_time', 'wheels_off', 'dep_time']
df.dropna(subset = DropNull, inplace = True)

# %%
#Null value checking
percent = df.isnull().sum().sort_values(ascending=False)/500000
total = df.isnull().sum().sort_values(ascending=False)
print(total)
# Out:
# fl_date                        0
# distance                       0
# arr_delay                      0
# cancelled                      0
# diverted                       0
# dup                            0
# crs_elapsed_time               0
# actual_elapsed_time            0
# air_time                       0
# flights                        0
# air_time_missing               0
# mkt_unique_carrier             0
# actual_elapsed_time_missing    0
# arr_delay_missing              0
# wheels_on_missing              0
# taxi_in_missing                0
# arr_time_missing               0
# wheels_off_missing             0
# taxi_out_missing               0
# dep_delay_missing              0
# arr_time                       0
# crs_arr_time                   0
# taxi_in                        0
# wheels_on                      0
# branded_code_share             0
# mkt_carrier                    0
# mkt_carrier_fl_num             0
# op_unique_carrier              0
# tail_num                       0
# op_carrier_fl_num              0
# origin_airport_id              0
# origin                         0
# origin_city_name               0
# dest_airport_id                0
# dest                           0
# dest_city_name                 0
# crs_dep_time                   0
# dep_time                       0
# dep_delay                      0
# taxi_out                       0
# wheels_off                     0
# dep_time_missing               0
# dtype: int64

# %%
# Filling in object null values
df['tail_num'] = df['tail_num'].fillna('None')

# %%
# Final check
percent = df.isnull().sum().sort_values(ascending=False)/500000
total = df.isnull().sum().sort_values(ascending=False)
print(total)
# Out:
# fl_date                        0
# distance                       0
# arr_delay                      0
# cancelled                      0
# diverted                       0
# dup                            0
# crs_elapsed_time               0
# actual_elapsed_time            0
# air_time                       0
# flights                        0
# air_time_missing               0
# mkt_unique_carrier             0
# actual_elapsed_time_missing    0
# arr_delay_missing              0
# wheels_on_missing              0
# taxi_in_missing                0
# arr_time_missing               0
# wheels_off_missing             0
# taxi_out_missing               0
# dep_delay_missing              0
# arr_time                       0
# crs_arr_time                   0
# taxi_in                        0
# wheels_on                      0
# branded_code_share             0
# mkt_carrier                    0
# mkt_carrier_fl_num             0
# op_unique_carrier              0
# tail_num                       0
# op_carrier_fl_num              0
# origin_airport_id              0
# origin                         0
# origin_city_name               0
# dest_airport_id                0
# dest                           0
# dest_city_name                 0
# crs_dep_time                   0
# dep_time                       0
# dep_delay                      0
# taxi_out                       0
# wheels_off                     0
# dep_time_missing               0
# dtype: int64

# %% [markdown]
# # Dealing with Outliers and different Data types

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(26,15)})
ax = sns.boxplot(data = df)
plt.xticks(rotation=45)
plt.show()

# %%
# Removing redundant columns and turning values into correct data types
df = df.drop('mkt_carrier_fl_num', axis = 1)

# %%
df[['op_carrier_fl_num', 'origin_airport_id', 'dest_airport_id']] = df[['op_carrier_fl_num', 'origin_airport_id', 'dest_airport_id']].astype('str')
df['fl_date'] = pd.to_datetime(df['fl_date'])
df.dtypes
# Out:
# fl_date                        datetime64[ns]
# mkt_unique_carrier                     object
# branded_code_share                     object
# mkt_carrier                            object
# op_unique_carrier                      object
# tail_num                               object
# op_carrier_fl_num                      object
# origin_airport_id                      object
# origin                                 object
# origin_city_name                       object
# dest_airport_id                        object
# dest                                   object
# dest_city_name                         object
# crs_dep_time                            int64
# dep_time                              float64
# dep_delay                             float64
# taxi_out                              float64
# wheels_off                            float64
# wheels_on                             float64
# taxi_in                               float64
# crs_arr_time                            int64
# arr_time                              float64
# arr_delay                             float64
# cancelled                               int64
# diverted                                int64
# dup                                    object
# crs_elapsed_time                        int64
# actual_elapsed_time                   float64
# air_time                              float64
# flights                                 int64
# distance                                int64
# air_time_missing                        int64
# actual_elapsed_time_missing             int64
# arr_delay_missing                       int64
# wheels_on_missing                       int64
# taxi_in_missing                         int64
# arr_time_missing                        int64
# wheels_off_missing                      int64
# taxi_out_missing                        int64
# dep_delay_missing                       int64
# dep_time_missing                        int64
# dtype: object

# %%
final_columns = df.columns.tolist()
sns.set(rc = {'figure.figsize':(26,15)})
ax = sns.boxplot(data = df)
plt.xticks(rotation=45)
plt.show()

# %%
data = df['arr_delay']
sns.histplot(data = data, bins = 100)
# Out:
# <AxesSubplot:xlabel='arr_delay', ylabel='Count'>

# %%
data.mean()
# Out:
# 3.9573244084631827

# %%
# Dropping outliers
df = df.drop(df[df['arr_delay'] > 1000].index)
data = df['arr_delay']

# %%
sns.histplot(data = data, bins = 100)
# Out:
# <AxesSubplot:xlabel='arr_delay', ylabel='Count'>

# %%
df.shape
# Out:
# (491229, 41)

# %%
df.dtypes == object
# Out:
# fl_date                        False
# mkt_unique_carrier              True
# branded_code_share              True
# mkt_carrier                     True
# op_unique_carrier               True
# tail_num                        True
# op_carrier_fl_num               True
# origin_airport_id               True
# origin                          True
# origin_city_name                True
# dest_airport_id                 True
# dest                            True
# dest_city_name                  True
# crs_dep_time                   False
# dep_time                       False
# dep_delay                      False
# taxi_out                       False
# wheels_off                     False
# wheels_on                      False
# taxi_in                        False
# crs_arr_time                   False
# arr_time                       False
# arr_delay                      False
# cancelled                      False
# diverted                       False
# dup                             True
# crs_elapsed_time               False
# actual_elapsed_time            False
# air_time                       False
# flights                        False
# distance                       False
# air_time_missing               False
# actual_elapsed_time_missing    False
# arr_delay_missing              False
# wheels_on_missing              False
# taxi_in_missing                False
# arr_time_missing               False
# wheels_off_missing             False
# taxi_out_missing               False
# dep_delay_missing              False
# dep_time_missing               False
# dtype: bool

# %%
df = df.drop(['mkt_carrier', 'origin', 'dest'], axis = 1)

# %%
final_columns = df.columns.tolist()
categorical_col = df.dtypes[final_columns][df.dtypes[final_columns] == object].index.tolist()
df[categorical_col].head(30)
# Out:
#    mkt_unique_carrier branded_code_share op_unique_carrier tail_num  \
# 9                  AA       AA_CODESHARE                YV   N908FJ
# 11                 NK                 NK                NK   N602NK
# 12                 NK                 NK                NK   N602NK
# 13                 NK                 NK                NK   N507NK
# 14                 NK                 NK                NK   N507NK
# 15                 NK                 NK                NK   N512NK
# 16                 NK                 NK                NK   N512NK
# 17                 NK                 NK                NK   N608NK
# 18                 NK                 NK                NK   N627NK
# 19                 NK                 NK                NK   N670NK
# 20                 NK                 NK                NK   N668NK
# 21                 NK                 NK                NK   N663NK
# 22                 NK                 NK                NK   N683NK
# 23                 NK                 NK                NK   N623NK
# 24                 NK                 NK                NK   N657NK
# 25                 NK                 NK                NK   N639NK
# 26                 NK                 NK                NK   N617NK
# 27                 NK                 NK                NK   N617NK
# 28                 NK                 NK                NK   N523NK
# 29                 NK                 NK                NK   N659NK
# 30                 NK                 NK                NK   N659NK
# 31                 NK                 NK                NK   N621NK
# 32                 NK                 NK                NK   N621NK
# 33                 NK                 NK                NK   N620NK
# 34                 NK                 NK                NK   N647NK
# 35                 NK                 NK                NK   N617NK
# 36                 NK                 NK                NK   N617NK
# 37                 NK                 NK                NK   N622NK
# 38                 NK                 NK                NK   N683NK
# 39                 NK                 NK                NK   N616NK
#
#    op_carrier_fl_num origin_airport_id     origin_city_name dest_airport_id  \
# 9               5948             14730       Louisville, KY           11298
# 11               395             14100     Philadelphia, PA           12889
# 12               396             12889        Las Vegas, NV           14100
# 13               403             10397          Atlanta, GA           11697
# 14               403             12892      Los Angeles, CA           10397
# 15               404             10397          Atlanta, GA           12892
# 16               404             11697  Fort Lauderdale, FL           10397
# 17               405             13204          Orlando, FL           11298
# 18               406             15304            Tampa, FL           10529
# 19               407             13204          Orlando, FL           11298
# 20               409             13930          Chicago, IL           11697
# 21               410             11697  Fort Lauderdale, FL           10821
# 22               414             11697  Fort Lauderdale, FL           10821
# 23               416             11697  Fort Lauderdale, FL           12265
# 24               417             11433          Detroit, MI           11697
# 25               419             11042        Cleveland, OH           11697
# 26               422             13204          Orlando, FL           10721
# 27               423             10721           Boston, MA           13204
# 28               424             12892      Los Angeles, CA           13487
# 29               425             11292           Denver, CO           13930
# 30               425             13930          Chicago, IL           11697
# 31               426             13204          Orlando, FL           13577
# 32               426             13577     Myrtle Beach, SC           10821
# 33               427             13487      Minneapolis, MN           15304
# 34               428             15304            Tampa, FL           13487
# 35               432             13204          Orlando, FL           10721
# 36               433             10721           Boston, MA           13204
# 37               440             11697  Fort Lauderdale, FL           11042
# 38               443             10821        Baltimore, MD           11697
# 39               445             11066         Columbus, OH           11697
#
#            dest_city_name dup
# 9   Dallas/Fort Worth, TX   N
# 11          Las Vegas, NV   N
# 12       Philadelphia, PA   N
# 13    Fort Lauderdale, FL   N
# 14            Atlanta, GA   N
# 15        Los Angeles, CA   N
# 16            Atlanta, GA   N
# 17  Dallas/Fort Worth, TX   N
# 18           Hartford, CT   N
# 19  Dallas/Fort Worth, TX   N
# 20    Fort Lauderdale, FL   N
# 21          Baltimore, MD   N
# 22          Baltimore, MD   N
# 23      Niagara Falls, NY   N
# 24    Fort Lauderdale, FL   N
# 25    Fort Lauderdale, FL   N
# 26             Boston, MA   N
# 27            Orlando, FL   N
# 28        Minneapolis, MN   N
# 29            Chicago, IL   N
# 30    Fort Lauderdale, FL   N
# 31       Myrtle Beach, SC   N
# 32          Baltimore, MD   N
# 33              Tampa, FL   N
# 34        Minneapolis, MN   N
# 35             Boston, MA   N
# 36            Orlando, FL   N
# 37          Cleveland, OH   N
# 38    Fort Lauderdale, FL   N
# 39    Fort Lauderdale, FL   N

# %% [markdown]
# # 1. Test the hypothesis that the delay is from a normal distribution and that the mean of the delay is 0

# %% [markdown]
# Without transformations the data is not from a normal distribution

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
data = df['arr_delay'].values.reshape(-1,1)
Std_scaler = StandardScaler()
MinMax_scaler = MinMaxScaler()
data = np.log(data)

sns.histplot(data = data, bins = 10)
# Out:
# C:\Users\JDPayne\AppData\Local\Temp/ipykernel_24108/358692645.py:5: RuntimeWarning: divide by zero encountered in log
#   data = np.log(data)
# C:\Users\JDPayne\AppData\Local\Temp/ipykernel_24108/358692645.py:5: RuntimeWarning: invalid value encountered in log
#   data = np.log(data)
# <AxesSubplot:ylabel='Count'>

# %%
delay_plot = df['arr_delay']
sns.histplot(data = delay_plot, bins = 100)
# Out:
# <AxesSubplot:xlabel='arr_delay', ylabel='Count'>

# %% [markdown]
# # 2. Is average/median monthly delay different during the year?

# %% [markdown]
# February and March have the highest delay means while december and april have the highest medians
#
# The increase in the median is probably because of the holidays where december is the christmas season and april is the end of most college semesters
#
# The increase in the mean is probably due to the changes in weather during february and march break

# %%
december = (df['fl_date'] > '2018-12-01') & (df['fl_date'] <='2018-12-31')
january = (df['fl_date'] > '2019-01-01') & (df['fl_date'] <='2019-01-31')
february = (df['fl_date'] > '2019-02-01') & (df['fl_date'] <='2019-02-28')
march = (df['fl_date'] > '2019-03-01') & (df['fl_date'] <='2019-03-31')
april = (df['fl_date'] > '2019-04-01') & (df['fl_date'] <='2019-04-30')
months = [december, january, february, march, april]

# %%
means = []
medians = []
for month in months:
    temp = df[month]['arr_delay'].mean()
    means.append(temp)
    temp = df[month]['arr_delay'].median()
    medians.append(temp)
months_str = ['december', 'january', 'february', 'march', 'april']
months_df = pd.DataFrame(zip(months_str,means,medians), columns = ['Month','Delay_mean', 'Delay_median']).set_index('Month')
months_df
# Out:
#           Delay_mean  Delay_median
# Month
# december    1.179531          -7.0
# january     1.455952          -7.0
# february    4.979049          -7.0
# march       3.269125          -7.0
# april       1.641417          -8.0

# %% [markdown]
# # 3. Does the weather affect the delay?

# %% [markdown]
# I will be using the most central state of the 4 main regions of the US to sample the weather.
#
# These will be the following
# * Utah will be used for the West
# * Iowa will be used for the Midwest
# * Mississippi will be used for the South
# * New York will be used for the NorthEast
#
# The first step will be to import the requests library and see if we can get a response from the https://www.worldweatheronline.com/ API

# %%
import requests as re
url = 'https://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=4a328e03abe24e6484b144126220407'
res = re.get(url)
res.status_code
# Out:
# 200

# %% [markdown]
# Now that we have a response we will make a list of cities we are interested in and convert our Datetime column into a list of unique strings and create a function that will call the API

# %%
Central_cities = ['New+York', 'Jackson', 'Des+Moines', 'Salt+Lake+City']
Flight_dates = df['fl_date']
Flight_dates = Flight_dates.dt.strftime('%Y-%m-%d').tolist()
temp = np.array(Flight_dates)
Flight_dates = np.unique(temp)

# %%
def api_call(City, date):
    
    '''
    This function takes a string value City formatted as 'New+York' if the name has multiple words and a date formatted as a string.
    
    This function will return a dictionary of hourly weather reports from 0 to 21hrs based on the City and Date input to the parameters.
    It will also return the specific date and city originally input
    '''
    
    
    api_key = '4a328e03abe24e6484b144126220407'
    url = 'https://api.worldweatheronline.com/premium/v1/past-weather.ashx'
    params_dict = {
        'q' : City,
        'date' : date,
        'format' : 'json',
        'key' : '4a328e03abe24e6484b144126220407'
    }
    
    header_dict = {
        'accept' : 'application/JSON'
    }
    
    r = re.get(url, headers = header_dict, params = params_dict).json()
    hourly_data = r['data']['weather'][0]['hourly']
    
    hours = [0,3,6,9,12,15,18,21]
    weather = []
       
    hourly_data = r['data']['weather'][0]['hourly']
    for item in hourly_data:
        weather.append(item['weatherDesc'][0]['value'])
        
    hourly_weather = dict(zip(hours, weather))
    city = r['data']['request'][0]['query']
    date = r['data']['weather'][0]['date']
    
    return hourly_weather, city, date

# %% [markdown]
# The next step will be to call the API multiple times with our dates and cities of interest and append the results into a dictionary

# %%
List_of_hourly_weathers = []    

for date in Flight_dates:    
    for City in Central_cities:
        hourly_weather = api_call(City, date)
        List_of_hourly_weathers.append(hourly_weather)
        
List_of_hourly_weathers
# Out:
# [({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Cloudy',
#    18: 'Light drizzle',
#    21: 'Light rain'},
#   'New York, United States of America',
#   '2018-12-01'),
#  ({0: 'Light drizzle',
#    3: 'Light rain',
#    6: 'Light rain',
#    9: 'Light rain',
#    12: 'Moderate rain',
#    15: 'Moderate rain at times',
#    18: 'Heavy rain at times',
#    21: 'Moderate or heavy rain shower'},
#   'Jacksonville, United States of America',
#   '2018-12-01'),
#  ({0: 'Light drizzle',
#    3: 'Overcast',
#    6: 'Light drizzle',
#    9: 'Moderate or heavy sleet',
#    12: 'Heavy rain',
#    15: 'Light drizzle',
#    18: 'Overcast',
#    21: 'Moderate rain'},
#   'Des Moines, United States of America',
#   '2018-12-01'),
#  ({0: 'Partly cloudy',
#    3: 'Moderate or heavy snow showers',
#    6: 'Partly cloudy',
#    9: 'Patchy light snow',
#    12: 'Partly cloudy',
#    15: 'Patchy light snow',
#    18: 'Partly cloudy',
#    21: 'Patchy heavy snow'},
#   'Salt Lake City, United States of America',
#   '2018-12-01'),
#  ({0: 'Overcast',
#    3: 'Moderate rain',
#    6: 'Moderate rain',
#    9: 'Moderate rain',
#    12: 'Moderate rain',
#    15: 'Mist',
#    18: 'Light drizzle',
#    21: 'Patchy light drizzle'},
#   'New York, United States of America',
#   '2018-12-02'),
#  ({0: 'Moderate rain at times',
#    3: 'Patchy rain possible',
#    6: 'Light rain shower',
#    9: 'Light rain shower',
#    12: 'Thundery outbreaks possible',
#    15: 'Moderate or heavy rain shower',
#    18: 'Moderate or heavy rain shower',
#    21: 'Patchy rain possible'},
#   'Jacksonville, United States of America',
#   '2018-12-02'),
#  ({0: 'Moderate rain',
#    3: 'Light sleet',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Overcast',
#    15: 'Heavy snow',
#    18: 'Overcast',
#    21: 'Heavy snow'},
#   'Des Moines, United States of America',
#   '2018-12-02'),
#  ({0: 'Partly cloudy',
#    3: 'Heavy snow',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Partly cloudy',
#    15: 'Patchy heavy snow',
#    18: 'Overcast',
#    21: 'Patchy heavy snow'},
#   'Salt Lake City, United States of America',
#   '2018-12-02'),
#  ({0: 'Patchy light drizzle',
#    3: 'Mist',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'New York, United States of America',
#   '2018-12-03'),
#  ({0: 'Light rain shower',
#    3: 'Light rain shower',
#    6: 'Light rain shower',
#    9: 'Light rain shower',
#    12: 'Light rain shower',
#    15: 'Light rain shower',
#    18: 'Cloudy',
#    21: 'Light rain shower'},
#   'Jacksonville, United States of America',
#   '2018-12-03'),
#  ({0: 'Overcast',
#    3: 'Overcast',
#    6: 'Light snow',
#    9: 'Moderate snow',
#    12: 'Moderate snow',
#    15: 'Light snow showers',
#    18: 'Moderate or heavy snow showers',
#    21: 'Light snow showers'},
#   'Des Moines, United States of America',
#   '2018-12-03'),
#  ({0: 'Partly cloudy',
#    3: 'Heavy snow',
#    6: 'Partly cloudy',
#    9: 'Patchy moderate snow',
#    12: 'Partly cloudy',
#    15: 'Patchy snow possible',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2018-12-03'),
#  ({0: 'Overcast',
#    3: 'Cloudy',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'New York, United States of America',
#   '2018-12-17'),
#  ({0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2018-12-17'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Des Moines, United States of America',
#   '2018-12-17'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Salt Lake City, United States of America',
#   '2018-12-17'),
#  ({0: 'Cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2018-12-18'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Cloudy',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2018-12-18'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'Des Moines, United States of America',
#   '2018-12-18'),
#  ({0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2018-12-18'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2018-12-19'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Cloudy',
#    12: 'Cloudy',
#    15: 'Partly cloudy',
#    18: 'Cloudy',
#    21: 'Moderate rain'},
#   'Jacksonville, United States of America',
#   '2018-12-19'),
#  ({0: 'Partly cloudy',
#    3: 'Overcast',
#    6: 'Light drizzle',
#    9: 'Patchy light drizzle',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Light drizzle'},
#   'Des Moines, United States of America',
#   '2018-12-19'),
#  ({0: 'Partly cloudy',
#    3: 'Patchy light drizzle',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2018-12-19'),
#  ({0: 'Overcast',
#    3: 'Light drizzle',
#    6: 'Patchy light drizzle',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-01-03'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Light rain shower',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2019-01-03'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Des Moines, United States of America',
#   '2019-01-03'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-01-03'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Cloudy',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'New York, United States of America',
#   '2019-01-04'),
#  ({0: 'Clear',
#    3: 'Mist',
#    6: 'Mist',
#    9: 'Sunny',
#    12: 'Patchy light drizzle',
#    15: 'Heavy rain',
#    18: 'Heavy rain at times',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-01-04'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Des Moines, United States of America',
#   '2019-01-04'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-01-04'),
#  ({0: 'Light drizzle',
#    3: 'Moderate rain',
#    6: 'Moderate or heavy rain with thunder',
#    9: 'Moderate or heavy rain with thunder',
#    12: 'Light rain shower',
#    15: 'Moderate rain',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-01-05'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2019-01-05'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Des Moines, United States of America',
#   '2019-01-05'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Partly cloudy',
#    18: 'Cloudy',
#    21: 'Cloudy'},
#   'Salt Lake City, United States of America',
#   '2019-01-05'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'New York, United States of America',
#   '2019-01-16'),
#  ({0: 'Partly cloudy',
#    3: 'Cloudy',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2019-01-16'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Overcast',
#    18: 'Overcast',
#    21: 'Light snow'},
#   'Des Moines, United States of America',
#   '2019-01-16'),
#  ({0: 'Partly cloudy',
#    3: 'Heavy snow',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Overcast',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Patchy light drizzle'},
#   'Salt Lake City, United States of America',
#   '2019-01-16'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Partly cloudy',
#    9: 'Cloudy',
#    12: 'Cloudy',
#    15: 'Overcast',
#    18: 'Cloudy',
#    21: 'Overcast'},
#   'New York, United States of America',
#   '2019-01-17'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-01-17'),
#  ({0: 'Moderate snow',
#    3: 'Moderate snow',
#    6: 'Mist',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Light snow',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'Des Moines, United States of America',
#   '2019-01-17'),
#  ({0: 'Partly cloudy',
#    3: 'Cloudy',
#    6: 'Cloudy',
#    9: 'Patchy light rain',
#    12: 'Overcast',
#    15: 'Moderate rain',
#    18: 'Mist',
#    21: 'Moderate or heavy rain with thunder'},
#   'Salt Lake City, United States of America',
#   '2019-01-17'),
#  ({0: 'Overcast',
#    3: 'Heavy snow',
#    6: 'Heavy snow',
#    9: 'Cloudy',
#    12: 'Overcast',
#    15: 'Overcast',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-01-18'),
#  ({0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Light rain shower',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-01-18'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Overcast',
#    9: 'Overcast',
#    12: 'Light snow',
#    15: 'Heavy snow',
#    18: 'Heavy snow',
#    21: 'Heavy snow'},
#   'Des Moines, United States of America',
#   '2019-01-18'),
#  ({0: 'Partly cloudy',
#    3: 'Moderate or heavy snow with thunder',
#    6: 'Cloudy',
#    9: 'Patchy heavy snow',
#    12: 'Partly cloudy',
#    15: 'Patchy light snow',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-01-18'),
#  ({0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Overcast',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'New York, United States of America',
#   '2019-02-01'),
#  ({0: 'Partly cloudy',
#    3: 'Overcast',
#    6: 'Patchy rain possible',
#    9: 'Patchy rain possible',
#    12: 'Light drizzle',
#    15: 'Light drizzle',
#    18: 'Light rain',
#    21: 'Patchy light drizzle'},
#   'Jacksonville, United States of America',
#   '2019-02-01'),
#  ({0: 'Light snow',
#    3: 'Freezing fog',
#    6: 'Freezing fog',
#    9: 'Freezing fog',
#    12: 'Mist',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Des Moines, United States of America',
#   '2019-02-01'),
#  ({0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Salt Lake City, United States of America',
#   '2019-02-01'),
#  ({0: 'Overcast',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-02-02'),
#  ({0: 'Light rain',
#    3: 'Light rain shower',
#    6: 'Moderate or heavy rain shower',
#    9: 'Light rain shower',
#    12: 'Light rain shower',
#    15: 'Overcast',
#    18: 'Cloudy',
#    21: 'Mist'},
#   'Jacksonville, United States of America',
#   '2019-02-02'),
#  ({0: 'Partly cloudy',
#    3: 'Cloudy',
#    6: 'Cloudy',
#    9: 'Overcast',
#    12: 'Light drizzle',
#    15: 'Overcast',
#    18: 'Overcast',
#    21: 'Overcast'},
#   'Des Moines, United States of America',
#   '2019-02-02'),
#  ({0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Patchy light drizzle',
#    15: 'Patchy light rain',
#    18: 'Patchy light drizzle',
#    21: 'Patchy rain possible'},
#   'Salt Lake City, United States of America',
#   '2019-02-02'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-02-03'),
#  ({0: 'Mist',
#    3: 'Light rain shower',
#    6: 'Light rain shower',
#    9: 'Light rain shower',
#    12: 'Light rain shower',
#    15: 'Light rain shower',
#    18: 'Light rain shower',
#    21: 'Overcast'},
#   'Jacksonville, United States of America',
#   '2019-02-03'),
#  ({0: 'Overcast',
#    3: 'Overcast',
#    6: 'Overcast',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Overcast',
#    18: 'Overcast',
#    21: 'Light drizzle'},
#   'Des Moines, United States of America',
#   '2019-02-03'),
#  ({0: 'Cloudy',
#    3: 'Light rain',
#    6: 'Thundery outbreaks possible',
#    9: 'Moderate or heavy rain shower',
#    12: 'Partly cloudy',
#    15: 'Light rain shower',
#    18: 'Thundery outbreaks possible',
#    21: 'Light rain shower'},
#   'Salt Lake City, United States of America',
#   '2019-02-03'),
#  ({0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-02-16'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Overcast',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-02-16'),
#  ({0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Cloudy',
#    18: 'Overcast',
#    21: 'Heavy snow'},
#   'Des Moines, United States of America',
#   '2019-02-16'),
#  ({0: 'Overcast',
#    3: 'Patchy moderate snow',
#    6: 'Cloudy',
#    9: 'Moderate or heavy snow showers',
#    12: 'Partly cloudy',
#    15: 'Patchy snow possible',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Salt Lake City, United States of America',
#   '2019-02-16'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Moderate snow'},
#   'New York, United States of America',
#   '2019-02-17'),
#  ({0: 'Clear',
#    3: 'Mist',
#    6: 'Fog',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Light rain shower',
#    18: 'Light rain shower',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-02-17'),
#  ({0: 'Heavy snow',
#    3: 'Heavy snow',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Overcast',
#    15: 'Heavy snow',
#    18: 'Overcast',
#    21: 'Heavy snow'},
#   'Des Moines, United States of America',
#   '2019-02-17'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Patchy light snow',
#    12: 'Cloudy',
#    15: 'Light snow',
#    18: 'Cloudy',
#    21: 'Heavy snow'},
#   'Salt Lake City, United States of America',
#   '2019-02-17'),
#  ({0: 'Light sleet',
#    3: 'Light rain',
#    6: 'Light rain',
#    9: 'Partly cloudy',
#    12: 'Overcast',
#    15: 'Blowing snow',
#    18: 'Patchy snow possible',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-02-18'),
#  ({0: 'Clear',
#    3: 'Mist',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Light rain shower',
#    18: 'Overcast',
#    21: 'Overcast'},
#   'Jacksonville, United States of America',
#   '2019-02-18'),
#  ({0: 'Overcast',
#    3: 'Moderate snow',
#    6: 'Mist',
#    9: 'Mist',
#    12: 'Cloudy',
#    15: 'Light snow',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'Des Moines, United States of America',
#   '2019-02-18'),
#  ({0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Patchy light snow',
#    18: 'Partly cloudy',
#    21: 'Patchy moderate snow'},
#   'Salt Lake City, United States of America',
#   '2019-02-18'),
#  ({0: 'Overcast',
#    3: 'Moderate snow',
#    6: 'Heavy snow',
#    9: 'Moderate snow',
#    12: 'Moderate snow',
#    15: 'Overcast',
#    18: 'Overcast',
#    21: 'Overcast'},
#   'New York, United States of America',
#   '2019-03-01'),
#  ({0: 'Overcast',
#    3: 'Cloudy',
#    6: 'Overcast',
#    9: 'Cloudy',
#    12: 'Light drizzle',
#    15: 'Moderate or heavy rain shower',
#    18: 'Moderate or heavy rain shower',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2019-03-01'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Cloudy',
#    18: 'Overcast',
#    21: 'Light snow'},
#   'Des Moines, United States of America',
#   '2019-03-01'),
#  ({0: 'Thundery outbreaks possible',
#    3: 'Patchy light drizzle',
#    6: 'Partly cloudy',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Patchy light drizzle'},
#   'Salt Lake City, United States of America',
#   '2019-03-01'),
#  ({0: 'Overcast',
#    3: 'Moderate or heavy sleet',
#    6: 'Moderate or heavy sleet',
#    9: 'Light sleet',
#    12: 'Overcast',
#    15: 'Cloudy',
#    18: 'Cloudy',
#    21: 'Partly cloudy'},
#   'New York, United States of America',
#   '2019-03-02'),
#  ({0: 'Patchy rain possible',
#    3: 'Mist',
#    6: 'Mist',
#    9: 'Patchy rain possible',
#    12: 'Light rain shower',
#    15: 'Moderate or heavy rain shower',
#    18: 'Moderate or heavy rain shower',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-03-02'),
#  ({0: 'Patchy light snow',
#    3: 'Partly cloudy',
#    6: 'Cloudy',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Overcast',
#    18: 'Light snow',
#    21: 'Moderate snow'},
#   'Des Moines, United States of America',
#   '2019-03-02'),
#  ({0: 'Cloudy',
#    3: 'Patchy heavy snow',
#    6: 'Partly cloudy',
#    9: 'Patchy moderate snow',
#    12: 'Cloudy',
#    15: 'Heavy snow',
#    18: 'Overcast',
#    21: 'Heavy snow'},
#   'Salt Lake City, United States of America',
#   '2019-03-02'),
#  ({0: 'Cloudy',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Overcast',
#    18: 'Heavy snow',
#    21: 'Heavy snow'},
#   'New York, United States of America',
#   '2019-03-03'),
#  ({0: 'Light rain shower',
#    3: 'Patchy rain possible',
#    6: 'Light rain shower',
#    9: 'Light rain shower',
#    12: 'Light rain shower',
#    15: 'Patchy rain possible',
#    18: 'Patchy rain possible',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2019-03-03'),
#  ({0: 'Moderate snow',
#    3: 'Light snow',
#    6: 'Light snow',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Cloudy',
#    21: 'Partly cloudy'},
#   'Des Moines, United States of America',
#   '2019-03-03'),
#  ({0: 'Cloudy',
#    3: 'Heavy snow',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Cloudy',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-03-03'),
#  ({0: 'Moderate or heavy rain shower',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-03-16'),
#  ({0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Patchy light drizzle',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-03-16'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Des Moines, United States of America',
#   '2019-03-16'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-03-16'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-03-17'),
#  ({0: 'Partly cloudy',
#    3: 'Cloudy',
#    6: 'Light rain',
#    9: 'Light rain',
#    12: 'Light rain',
#    15: 'Patchy light drizzle',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-03-17'),
#  ({0: 'Cloudy',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Des Moines, United States of America',
#   '2019-03-17'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-03-17'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-03-18'),
#  ({0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Jacksonville, United States of America',
#   '2019-03-18'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Cloudy'},
#   'Des Moines, United States of America',
#   '2019-03-18'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-03-18'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-04-01'),
#  ({0: 'Moderate or heavy rain shower',
#    3: 'Cloudy',
#    6: 'Light rain',
#    9: 'Heavy rain',
#    12: 'Heavy rain',
#    15: 'Light rain',
#    18: 'Moderate rain',
#    21: 'Light rain shower'},
#   'Jacksonville, United States of America',
#   '2019-04-01'),
#  ({0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Des Moines, United States of America',
#   '2019-04-01'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Cloudy'},
#   'Salt Lake City, United States of America',
#   '2019-04-01'),
#  ({0: 'Cloudy',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Cloudy',
#    18: 'Partly cloudy',
#    21: 'Patchy light rain'},
#   'New York, United States of America',
#   '2019-04-02'),
#  ({0: 'Moderate or heavy rain with thunder',
#    3: 'Fog',
#    6: 'Moderate rain',
#    9: 'Patchy light rain',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2019-04-02'),
#  ({0: 'Overcast',
#    3: 'Light drizzle',
#    6: 'Light sleet',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Des Moines, United States of America',
#   '2019-04-02'),
#  ({0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Patchy light rain',
#    18: 'Partly cloudy',
#    21: 'Patchy light rain'},
#   'Salt Lake City, United States of America',
#   '2019-04-02'),
#  ({0: 'Cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-04-03'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Overcast'},
#   'Jacksonville, United States of America',
#   '2019-04-03'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Patchy light rain',
#    18: 'Overcast',
#    21: 'Moderate rain'},
#   'Des Moines, United States of America',
#   '2019-04-03'),
#  ({0: 'Overcast',
#    3: 'Patchy light drizzle',
#    6: 'Patchy light drizzle',
#    9: 'Patchy light rain',
#    12: 'Patchy light drizzle',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-04-03'),
#  ({0: 'Light drizzle',
#    3: 'Patchy light drizzle',
#    6: 'Patchy light drizzle',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'New York, United States of America',
#   '2019-04-17'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Cloudy',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2019-04-17'),
#  ({0: 'Light rain shower',
#    3: 'Light rain shower',
#    6: 'Overcast',
#    9: 'Light rain shower',
#    12: 'Thundery outbreaks possible',
#    15: 'Light rain shower',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'Des Moines, United States of America',
#   '2019-04-17'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-04-17'),
#  ({0: 'Cloudy',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Light drizzle',
#    12: 'Patchy light drizzle',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'New York, United States of America',
#   '2019-04-18'),
#  ({0: 'Overcast',
#    3: 'Clear',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Patchy rain possible'},
#   'Jacksonville, United States of America',
#   '2019-04-18'),
#  ({0: 'Cloudy',
#    3: 'Overcast',
#    6: 'Overcast',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Cloudy',
#    18: 'Patchy rain possible',
#    21: 'Partly cloudy'},
#   'Des Moines, United States of America',
#   '2019-04-18'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Salt Lake City, United States of America',
#   '2019-04-18'),
#  ({0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Patchy rain possible',
#    18: 'Light rain shower',
#    21: 'Light rain shower'},
#   'New York, United States of America',
#   '2019-04-19'),
#  ({0: 'Patchy rain possible',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Patchy rain possible',
#    12: 'Moderate or heavy rain shower',
#    15: 'Moderate rain at times',
#    18: 'Clear',
#    21: 'Clear'},
#   'Jacksonville, United States of America',
#   '2019-04-19'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'Des Moines, United States of America',
#   '2019-04-19'),
#  ({0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Overcast'},
#   'Salt Lake City, United States of America',
#   '2019-04-19')]

# %% [markdown]
# Now that we have our weather information we will separate the dest_city_name column in the main df into 2 separate columns and group the states by the regions West, Midwest, South and Northeast

# %%
df[['City', 'State']] = df['dest_city_name'].str.split(pat= ',', expand = True)
df[['City', 'State']] = df[['City', 'State']].astype('str')
df
# Out:
#          fl_date mkt_unique_carrier branded_code_share op_unique_carrier  \
# 9     2018-12-01                 AA       AA_CODESHARE                YV
# 11    2018-12-01                 NK                 NK                NK
# 12    2018-12-01                 NK                 NK                NK
# 13    2018-12-01                 NK                 NK                NK
# 14    2018-12-01                 NK                 NK                NK
# ...          ...                ...                ...               ...
# 49995 2019-04-19                 UA       UA_CODESHARE                AX
# 49996 2019-04-19                 UA       UA_CODESHARE                AX
# 49997 2019-04-19                 UA       UA_CODESHARE                AX
# 49998 2019-04-19                 UA       UA_CODESHARE                AX
# 49999 2019-04-19                 UA       UA_CODESHARE                AX
#
#       tail_num op_carrier_fl_num origin_airport_id  origin_city_name  \
# 9       N908FJ              5948             14730    Louisville, KY
# 11      N602NK               395             14100  Philadelphia, PA
# 12      N602NK               396             12889     Las Vegas, NV
# 13      N507NK               403             10397       Atlanta, GA
# 14      N507NK               403             12892   Los Angeles, CA
# ...        ...               ...               ...               ...
# 49995   N11113              4744             11292        Denver, CO
# 49996   N21129              4743             11637         Fargo, ND
# 49997   N846HK              4742             12389     Williston, ND
# 49998   N11121              4741             12389     Williston, ND
# 49999   N41104              4740             13342     Milwaukee, WI
#
#       dest_airport_id         dest_city_name  ...  arr_delay_missing  \
# 9               11298  Dallas/Fort Worth, TX  ...                  0
# 11              12889          Las Vegas, NV  ...                  0
# 12              14100       Philadelphia, PA  ...                  0
# 13              11697    Fort Lauderdale, FL  ...                  0
# 14              10397            Atlanta, GA  ...                  0
# ...               ...                    ...  ...                ...
# 49995           15016          St. Louis, MO  ...                  0
# 49996           13930            Chicago, IL  ...                  0
# 49997           11292             Denver, CO  ...                  0
# 49998           11292             Denver, CO  ...                  0
# 49999           13930            Chicago, IL  ...                  0
#
#        wheels_on_missing  taxi_in_missing  arr_time_missing  \
# 9                      0                0                 0
# 11                     0                0                 0
# 12                     0                0                 0
# 13                     0                0                 0
# 14                     0                0                 0
# ...                  ...              ...               ...
# 49995                  0                0                 0
# 49996                  0                0                 0
# 49997                  0                0                 0
# 49998                  0                0                 0
# 49999                  0                0                 0
#
#        wheels_off_missing  taxi_out_missing  dep_delay_missing  \
# 9                       0                 0                  0
# 11                      0                 0                  0
# 12                      0                 0                  0
# 13                      0                 0                  0
# 14                      0                 0                  0
# ...                   ...               ...                ...
# 49995                   0                 0                  0
# 49996                   0                 0                  0
# 49997                   0                 0                  0
# 49998                   0                 0                  0
# 49999                   0                 0                  0
#
#        dep_time_missing               City  State
# 9                     0  Dallas/Fort Worth     TX
# 11                    0          Las Vegas     NV
# 12                    0       Philadelphia     PA
# 13                    0    Fort Lauderdale     FL
# 14                    0            Atlanta     GA
# ...                 ...                ...    ...
# 49995                 0          St. Louis     MO
# 49996                 0            Chicago     IL
# 49997                 0             Denver     CO
# 49998                 0             Denver     CO
# 49999                 0            Chicago     IL
#
# [491229 rows x 40 columns]

# %%
West = [' WA', ' OR', ' ID', ' MT', ' WY', ' CO', ' NM', ' AZ', ' UT', ' NV', ' CA']
Midwest = [' ND',' SD', ' NE', ' KS', ' MN', ' IA', ' MO', ' WI', ' IL', ' IN', ' OH', ' MI']
South =  [' TX', ' OK', ' AR', ' LA', ' MS', ' AL', ' TN', ' AL', ' GA', ' KY', ' FL', ' SC', ' NC', ' WV', ' DC', ' MD', ' DE']
Northeast = [' PA', ' NY', ' NJ', ' CT', ' MA', ' RI', ' VT', ' NH', ' ME']

#Checking total of mainland states + DC
total = len(West) + len(Midwest) + len(South) + len(Northeast)
total
# Out:
# 49

# %%
df['Region'] = ''
df
# Out:
#          fl_date mkt_unique_carrier branded_code_share op_unique_carrier  \
# 9     2018-12-01                 AA       AA_CODESHARE                YV
# 11    2018-12-01                 NK                 NK                NK
# 12    2018-12-01                 NK                 NK                NK
# 13    2018-12-01                 NK                 NK                NK
# 14    2018-12-01                 NK                 NK                NK
# ...          ...                ...                ...               ...
# 49995 2019-04-19                 UA       UA_CODESHARE                AX
# 49996 2019-04-19                 UA       UA_CODESHARE                AX
# 49997 2019-04-19                 UA       UA_CODESHARE                AX
# 49998 2019-04-19                 UA       UA_CODESHARE                AX
# 49999 2019-04-19                 UA       UA_CODESHARE                AX
#
#       tail_num op_carrier_fl_num origin_airport_id  origin_city_name  \
# 9       N908FJ              5948             14730    Louisville, KY
# 11      N602NK               395             14100  Philadelphia, PA
# 12      N602NK               396             12889     Las Vegas, NV
# 13      N507NK               403             10397       Atlanta, GA
# 14      N507NK               403             12892   Los Angeles, CA
# ...        ...               ...               ...               ...
# 49995   N11113              4744             11292        Denver, CO
# 49996   N21129              4743             11637         Fargo, ND
# 49997   N846HK              4742             12389     Williston, ND
# 49998   N11121              4741             12389     Williston, ND
# 49999   N41104              4740             13342     Milwaukee, WI
#
#       dest_airport_id         dest_city_name  ...  wheels_on_missing  \
# 9               11298  Dallas/Fort Worth, TX  ...                  0
# 11              12889          Las Vegas, NV  ...                  0
# 12              14100       Philadelphia, PA  ...                  0
# 13              11697    Fort Lauderdale, FL  ...                  0
# 14              10397            Atlanta, GA  ...                  0
# ...               ...                    ...  ...                ...
# 49995           15016          St. Louis, MO  ...                  0
# 49996           13930            Chicago, IL  ...                  0
# 49997           11292             Denver, CO  ...                  0
# 49998           11292             Denver, CO  ...                  0
# 49999           13930            Chicago, IL  ...                  0
#
#        taxi_in_missing  arr_time_missing  wheels_off_missing  \
# 9                    0                 0                   0
# 11                   0                 0                   0
# 12                   0                 0                   0
# 13                   0                 0                   0
# 14                   0                 0                   0
# ...                ...               ...                 ...
# 49995                0                 0                   0
# 49996                0                 0                   0
# 49997                0                 0                   0
# 49998                0                 0                   0
# 49999                0                 0                   0
#
#        taxi_out_missing  dep_delay_missing  dep_time_missing  \
# 9                     0                  0                 0
# 11                    0                  0                 0
# 12                    0                  0                 0
# 13                    0                  0                 0
# 14                    0                  0                 0
# ...                 ...                ...               ...
# 49995                 0                  0                 0
# 49996                 0                  0                 0
# 49997                 0                  0                 0
# 49998                 0                  0                 0
# 49999                 0                  0                 0
#
#                     City  State  Region
# 9      Dallas/Fort Worth     TX
# 11             Las Vegas     NV
# 12          Philadelphia     PA
# 13       Fort Lauderdale     FL
# 14               Atlanta     GA
# ...                  ...    ...     ...
# 49995          St. Louis     MO
# 49996            Chicago     IL
# 49997             Denver     CO
# 49998             Denver     CO
# 49999            Chicago     IL
#
# [491229 rows x 41 columns]

# %%
df.loc[df['State'].isin(South), ['Region']] = 'South'
df.loc[df['State'].isin(Northeast), ['Region']] = 'NorthEast'
df.loc[df['State'].isin(West), ['Region']] = 'West'
df.loc[df['State'].isin(Midwest), ['Region']] = 'MidWest'
df
# Out:
#          fl_date mkt_unique_carrier branded_code_share op_unique_carrier  \
# 9     2018-12-01                 AA       AA_CODESHARE                YV
# 11    2018-12-01                 NK                 NK                NK
# 12    2018-12-01                 NK                 NK                NK
# 13    2018-12-01                 NK                 NK                NK
# 14    2018-12-01                 NK                 NK                NK
# ...          ...                ...                ...               ...
# 49995 2019-04-19                 UA       UA_CODESHARE                AX
# 49996 2019-04-19                 UA       UA_CODESHARE                AX
# 49997 2019-04-19                 UA       UA_CODESHARE                AX
# 49998 2019-04-19                 UA       UA_CODESHARE                AX
# 49999 2019-04-19                 UA       UA_CODESHARE                AX
#
#       tail_num op_carrier_fl_num origin_airport_id  origin_city_name  \
# 9       N908FJ              5948             14730    Louisville, KY
# 11      N602NK               395             14100  Philadelphia, PA
# 12      N602NK               396             12889     Las Vegas, NV
# 13      N507NK               403             10397       Atlanta, GA
# 14      N507NK               403             12892   Los Angeles, CA
# ...        ...               ...               ...               ...
# 49995   N11113              4744             11292        Denver, CO
# 49996   N21129              4743             11637         Fargo, ND
# 49997   N846HK              4742             12389     Williston, ND
# 49998   N11121              4741             12389     Williston, ND
# 49999   N41104              4740             13342     Milwaukee, WI
#
#       dest_airport_id         dest_city_name  ...  wheels_on_missing  \
# 9               11298  Dallas/Fort Worth, TX  ...                  0
# 11              12889          Las Vegas, NV  ...                  0
# 12              14100       Philadelphia, PA  ...                  0
# 13              11697    Fort Lauderdale, FL  ...                  0
# 14              10397            Atlanta, GA  ...                  0
# ...               ...                    ...  ...                ...
# 49995           15016          St. Louis, MO  ...                  0
# 49996           13930            Chicago, IL  ...                  0
# 49997           11292             Denver, CO  ...                  0
# 49998           11292             Denver, CO  ...                  0
# 49999           13930            Chicago, IL  ...                  0
#
#        taxi_in_missing  arr_time_missing  wheels_off_missing  \
# 9                    0                 0                   0
# 11                   0                 0                   0
# 12                   0                 0                   0
# 13                   0                 0                   0
# 14                   0                 0                   0
# ...                ...               ...                 ...
# 49995                0                 0                   0
# 49996                0                 0                   0
# 49997                0                 0                   0
# 49998                0                 0                   0
# 49999                0                 0                   0
#
#        taxi_out_missing  dep_delay_missing  dep_time_missing  \
# 9                     0                  0                 0
# 11                    0                  0                 0
# 12                    0                  0                 0
# 13                    0                  0                 0
# 14                    0                  0                 0
# ...                 ...                ...               ...
# 49995                 0                  0                 0
# 49996                 0                  0                 0
# 49997                 0                  0                 0
# 49998                 0                  0                 0
# 49999                 0                  0                 0
#
#                     City  State     Region
# 9      Dallas/Fort Worth     TX      South
# 11             Las Vegas     NV       West
# 12          Philadelphia     PA  NorthEast
# 13       Fort Lauderdale     FL      South
# 14               Atlanta     GA      South
# ...                  ...    ...        ...
# 49995          St. Louis     MO    MidWest
# 49996            Chicago     IL    MidWest
# 49997             Denver     CO       West
# 49998             Denver     CO       West
# 49999            Chicago     IL    MidWest
#
# [491229 rows x 41 columns]

# %%
#Replace the city names with the regions i defined earlier
import copy
Final_weather_report = copy.deepcopy(List_of_hourly_weathers)
Final_weather_report
# Out:
# [[{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Cloudy',
#    18: 'Light drizzle',
#    21: 'Light rain'},
#   'NorthEast',
#   '2018-12-01'],
#  [{0: 'Light drizzle',
#    3: 'Light rain',
#    6: 'Light rain',
#    9: 'Light rain',
#    12: 'Moderate rain',
#    15: 'Moderate rain at times',
#    18: 'Heavy rain at times',
#    21: 'Moderate or heavy rain shower'},
#   'South',
#   '2018-12-01'],
#  [{0: 'Light drizzle',
#    3: 'Overcast',
#    6: 'Light drizzle',
#    9: 'Moderate or heavy sleet',
#    12: 'Heavy rain',
#    15: 'Light drizzle',
#    18: 'Overcast',
#    21: 'Moderate rain'},
#   'MidWest',
#   '2018-12-01'],
#  [{0: 'Partly cloudy',
#    3: 'Moderate or heavy snow showers',
#    6: 'Partly cloudy',
#    9: 'Patchy light snow',
#    12: 'Partly cloudy',
#    15: 'Patchy light snow',
#    18: 'Partly cloudy',
#    21: 'Patchy heavy snow'},
#   'West',
#   '2018-12-01'],
#  [{0: 'Overcast',
#    3: 'Moderate rain',
#    6: 'Moderate rain',
#    9: 'Moderate rain',
#    12: 'Moderate rain',
#    15: 'Mist',
#    18: 'Light drizzle',
#    21: 'Patchy light drizzle'},
#   'NorthEast',
#   '2018-12-02'],
#  [{0: 'Moderate rain at times',
#    3: 'Patchy rain possible',
#    6: 'Light rain shower',
#    9: 'Light rain shower',
#    12: 'Thundery outbreaks possible',
#    15: 'Moderate or heavy rain shower',
#    18: 'Moderate or heavy rain shower',
#    21: 'Patchy rain possible'},
#   'South',
#   '2018-12-02'],
#  [{0: 'Moderate rain',
#    3: 'Light sleet',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Overcast',
#    15: 'Heavy snow',
#    18: 'Overcast',
#    21: 'Heavy snow'},
#   'MidWest',
#   '2018-12-02'],
#  [{0: 'Partly cloudy',
#    3: 'Heavy snow',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Partly cloudy',
#    15: 'Patchy heavy snow',
#    18: 'Overcast',
#    21: 'Patchy heavy snow'},
#   'West',
#   '2018-12-02'],
#  [{0: 'Patchy light drizzle',
#    3: 'Mist',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'NorthEast',
#   '2018-12-03'],
#  [{0: 'Light rain shower',
#    3: 'Light rain shower',
#    6: 'Light rain shower',
#    9: 'Light rain shower',
#    12: 'Light rain shower',
#    15: 'Light rain shower',
#    18: 'Cloudy',
#    21: 'Light rain shower'},
#   'South',
#   '2018-12-03'],
#  [{0: 'Overcast',
#    3: 'Overcast',
#    6: 'Light snow',
#    9: 'Moderate snow',
#    12: 'Moderate snow',
#    15: 'Light snow showers',
#    18: 'Moderate or heavy snow showers',
#    21: 'Light snow showers'},
#   'MidWest',
#   '2018-12-03'],
#  [{0: 'Partly cloudy',
#    3: 'Heavy snow',
#    6: 'Partly cloudy',
#    9: 'Patchy moderate snow',
#    12: 'Partly cloudy',
#    15: 'Patchy snow possible',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2018-12-03'],
#  [{0: 'Overcast',
#    3: 'Cloudy',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'NorthEast',
#   '2018-12-17'],
#  [{0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'South',
#   '2018-12-17'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'MidWest',
#   '2018-12-17'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'West',
#   '2018-12-17'],
#  [{0: 'Cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2018-12-18'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Cloudy',
#    21: 'Partly cloudy'},
#   'South',
#   '2018-12-18'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'MidWest',
#   '2018-12-18'],
#  [{0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2018-12-18'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2018-12-19'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Cloudy',
#    12: 'Cloudy',
#    15: 'Partly cloudy',
#    18: 'Cloudy',
#    21: 'Moderate rain'},
#   'South',
#   '2018-12-19'],
#  [{0: 'Partly cloudy',
#    3: 'Overcast',
#    6: 'Light drizzle',
#    9: 'Patchy light drizzle',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Light drizzle'},
#   'MidWest',
#   '2018-12-19'],
#  [{0: 'Partly cloudy',
#    3: 'Patchy light drizzle',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2018-12-19'],
#  [{0: 'Overcast',
#    3: 'Light drizzle',
#    6: 'Patchy light drizzle',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-01-03'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Light rain shower',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'South',
#   '2019-01-03'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'MidWest',
#   '2019-01-03'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2019-01-03'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Cloudy',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'NorthEast',
#   '2019-01-04'],
#  [{0: 'Clear',
#    3: 'Mist',
#    6: 'Mist',
#    9: 'Sunny',
#    12: 'Patchy light drizzle',
#    15: 'Heavy rain',
#    18: 'Heavy rain at times',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-01-04'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'MidWest',
#   '2019-01-04'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'West',
#   '2019-01-04'],
#  [{0: 'Light drizzle',
#    3: 'Moderate rain',
#    6: 'Moderate or heavy rain with thunder',
#    9: 'Moderate or heavy rain with thunder',
#    12: 'Light rain shower',
#    15: 'Moderate rain',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-01-05'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'South',
#   '2019-01-05'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'MidWest',
#   '2019-01-05'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Partly cloudy',
#    18: 'Cloudy',
#    21: 'Cloudy'},
#   'West',
#   '2019-01-05'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'NorthEast',
#   '2019-01-16'],
#  [{0: 'Partly cloudy',
#    3: 'Cloudy',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'South',
#   '2019-01-16'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Overcast',
#    18: 'Overcast',
#    21: 'Light snow'},
#   'MidWest',
#   '2019-01-16'],
#  [{0: 'Partly cloudy',
#    3: 'Heavy snow',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Overcast',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Patchy light drizzle'},
#   'West',
#   '2019-01-16'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Partly cloudy',
#    9: 'Cloudy',
#    12: 'Cloudy',
#    15: 'Overcast',
#    18: 'Cloudy',
#    21: 'Overcast'},
#   'NorthEast',
#   '2019-01-17'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-01-17'],
#  [{0: 'Moderate snow',
#    3: 'Moderate snow',
#    6: 'Mist',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Light snow',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'MidWest',
#   '2019-01-17'],
#  [{0: 'Partly cloudy',
#    3: 'Cloudy',
#    6: 'Cloudy',
#    9: 'Patchy light rain',
#    12: 'Overcast',
#    15: 'Moderate rain',
#    18: 'Mist',
#    21: 'Moderate or heavy rain with thunder'},
#   'West',
#   '2019-01-17'],
#  [{0: 'Overcast',
#    3: 'Heavy snow',
#    6: 'Heavy snow',
#    9: 'Cloudy',
#    12: 'Overcast',
#    15: 'Overcast',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-01-18'],
#  [{0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Light rain shower',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-01-18'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Overcast',
#    9: 'Overcast',
#    12: 'Light snow',
#    15: 'Heavy snow',
#    18: 'Heavy snow',
#    21: 'Heavy snow'},
#   'MidWest',
#   '2019-01-18'],
#  [{0: 'Partly cloudy',
#    3: 'Moderate or heavy snow with thunder',
#    6: 'Cloudy',
#    9: 'Patchy heavy snow',
#    12: 'Partly cloudy',
#    15: 'Patchy light snow',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2019-01-18'],
#  [{0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Overcast',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'NorthEast',
#   '2019-02-01'],
#  [{0: 'Partly cloudy',
#    3: 'Overcast',
#    6: 'Patchy rain possible',
#    9: 'Patchy rain possible',
#    12: 'Light drizzle',
#    15: 'Light drizzle',
#    18: 'Light rain',
#    21: 'Patchy light drizzle'},
#   'South',
#   '2019-02-01'],
#  [{0: 'Light snow',
#    3: 'Freezing fog',
#    6: 'Freezing fog',
#    9: 'Freezing fog',
#    12: 'Mist',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'MidWest',
#   '2019-02-01'],
#  [{0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'West',
#   '2019-02-01'],
#  [{0: 'Overcast',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-02-02'],
#  [{0: 'Light rain',
#    3: 'Light rain shower',
#    6: 'Moderate or heavy rain shower',
#    9: 'Light rain shower',
#    12: 'Light rain shower',
#    15: 'Overcast',
#    18: 'Cloudy',
#    21: 'Mist'},
#   'South',
#   '2019-02-02'],
#  [{0: 'Partly cloudy',
#    3: 'Cloudy',
#    6: 'Cloudy',
#    9: 'Overcast',
#    12: 'Light drizzle',
#    15: 'Overcast',
#    18: 'Overcast',
#    21: 'Overcast'},
#   'MidWest',
#   '2019-02-02'],
#  [{0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Patchy light drizzle',
#    15: 'Patchy light rain',
#    18: 'Patchy light drizzle',
#    21: 'Patchy rain possible'},
#   'West',
#   '2019-02-02'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-02-03'],
#  [{0: 'Mist',
#    3: 'Light rain shower',
#    6: 'Light rain shower',
#    9: 'Light rain shower',
#    12: 'Light rain shower',
#    15: 'Light rain shower',
#    18: 'Light rain shower',
#    21: 'Overcast'},
#   'South',
#   '2019-02-03'],
#  [{0: 'Overcast',
#    3: 'Overcast',
#    6: 'Overcast',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Overcast',
#    18: 'Overcast',
#    21: 'Light drizzle'},
#   'MidWest',
#   '2019-02-03'],
#  [{0: 'Cloudy',
#    3: 'Light rain',
#    6: 'Thundery outbreaks possible',
#    9: 'Moderate or heavy rain shower',
#    12: 'Partly cloudy',
#    15: 'Light rain shower',
#    18: 'Thundery outbreaks possible',
#    21: 'Light rain shower'},
#   'West',
#   '2019-02-03'],
#  [{0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-02-16'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Overcast',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-02-16'],
#  [{0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Cloudy',
#    18: 'Overcast',
#    21: 'Heavy snow'},
#   'MidWest',
#   '2019-02-16'],
#  [{0: 'Overcast',
#    3: 'Patchy moderate snow',
#    6: 'Cloudy',
#    9: 'Moderate or heavy snow showers',
#    12: 'Partly cloudy',
#    15: 'Patchy snow possible',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'West',
#   '2019-02-16'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Moderate snow'},
#   'NorthEast',
#   '2019-02-17'],
#  [{0: 'Clear',
#    3: 'Mist',
#    6: 'Fog',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Light rain shower',
#    18: 'Light rain shower',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-02-17'],
#  [{0: 'Heavy snow',
#    3: 'Heavy snow',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Overcast',
#    15: 'Heavy snow',
#    18: 'Overcast',
#    21: 'Heavy snow'},
#   'MidWest',
#   '2019-02-17'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Patchy light snow',
#    12: 'Cloudy',
#    15: 'Light snow',
#    18: 'Cloudy',
#    21: 'Heavy snow'},
#   'West',
#   '2019-02-17'],
#  [{0: 'Light sleet',
#    3: 'Light rain',
#    6: 'Light rain',
#    9: 'Partly cloudy',
#    12: 'Overcast',
#    15: 'Blowing snow',
#    18: 'Patchy snow possible',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-02-18'],
#  [{0: 'Clear',
#    3: 'Mist',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Light rain shower',
#    18: 'Overcast',
#    21: 'Overcast'},
#   'South',
#   '2019-02-18'],
#  [{0: 'Overcast',
#    3: 'Moderate snow',
#    6: 'Mist',
#    9: 'Mist',
#    12: 'Cloudy',
#    15: 'Light snow',
#    18: 'Clear',
#    21: 'Partly cloudy'},
#   'MidWest',
#   '2019-02-18'],
#  [{0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Patchy light snow',
#    18: 'Partly cloudy',
#    21: 'Patchy moderate snow'},
#   'West',
#   '2019-02-18'],
#  [{0: 'Overcast',
#    3: 'Moderate snow',
#    6: 'Heavy snow',
#    9: 'Moderate snow',
#    12: 'Moderate snow',
#    15: 'Overcast',
#    18: 'Overcast',
#    21: 'Overcast'},
#   'NorthEast',
#   '2019-03-01'],
#  [{0: 'Overcast',
#    3: 'Cloudy',
#    6: 'Overcast',
#    9: 'Cloudy',
#    12: 'Light drizzle',
#    15: 'Moderate or heavy rain shower',
#    18: 'Moderate or heavy rain shower',
#    21: 'Clear'},
#   'South',
#   '2019-03-01'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Cloudy',
#    18: 'Overcast',
#    21: 'Light snow'},
#   'MidWest',
#   '2019-03-01'],
#  [{0: 'Thundery outbreaks possible',
#    3: 'Patchy light drizzle',
#    6: 'Partly cloudy',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Patchy light drizzle'},
#   'West',
#   '2019-03-01'],
#  [{0: 'Overcast',
#    3: 'Moderate or heavy sleet',
#    6: 'Moderate or heavy sleet',
#    9: 'Light sleet',
#    12: 'Overcast',
#    15: 'Cloudy',
#    18: 'Cloudy',
#    21: 'Partly cloudy'},
#   'NorthEast',
#   '2019-03-02'],
#  [{0: 'Patchy rain possible',
#    3: 'Mist',
#    6: 'Mist',
#    9: 'Patchy rain possible',
#    12: 'Light rain shower',
#    15: 'Moderate or heavy rain shower',
#    18: 'Moderate or heavy rain shower',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-03-02'],
#  [{0: 'Patchy light snow',
#    3: 'Partly cloudy',
#    6: 'Cloudy',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Overcast',
#    18: 'Light snow',
#    21: 'Moderate snow'},
#   'MidWest',
#   '2019-03-02'],
#  [{0: 'Cloudy',
#    3: 'Patchy heavy snow',
#    6: 'Partly cloudy',
#    9: 'Patchy moderate snow',
#    12: 'Cloudy',
#    15: 'Heavy snow',
#    18: 'Overcast',
#    21: 'Heavy snow'},
#   'West',
#   '2019-03-02'],
#  [{0: 'Cloudy',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Overcast',
#    18: 'Heavy snow',
#    21: 'Heavy snow'},
#   'NorthEast',
#   '2019-03-03'],
#  [{0: 'Light rain shower',
#    3: 'Patchy rain possible',
#    6: 'Light rain shower',
#    9: 'Light rain shower',
#    12: 'Light rain shower',
#    15: 'Patchy rain possible',
#    18: 'Patchy rain possible',
#    21: 'Clear'},
#   'South',
#   '2019-03-03'],
#  [{0: 'Moderate snow',
#    3: 'Light snow',
#    6: 'Light snow',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Partly cloudy',
#    18: 'Cloudy',
#    21: 'Partly cloudy'},
#   'MidWest',
#   '2019-03-03'],
#  [{0: 'Cloudy',
#    3: 'Heavy snow',
#    6: 'Overcast',
#    9: 'Heavy snow',
#    12: 'Cloudy',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2019-03-03'],
#  [{0: 'Moderate or heavy rain shower',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-03-16'],
#  [{0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Patchy light drizzle',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-03-16'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'MidWest',
#   '2019-03-16'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2019-03-16'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-03-17'],
#  [{0: 'Partly cloudy',
#    3: 'Cloudy',
#    6: 'Light rain',
#    9: 'Light rain',
#    12: 'Light rain',
#    15: 'Patchy light drizzle',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-03-17'],
#  [{0: 'Cloudy',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'MidWest',
#   '2019-03-17'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2019-03-17'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-03-18'],
#  [{0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'South',
#   '2019-03-18'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Cloudy',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Cloudy'},
#   'MidWest',
#   '2019-03-18'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2019-03-18'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-04-01'],
#  [{0: 'Moderate or heavy rain shower',
#    3: 'Cloudy',
#    6: 'Light rain',
#    9: 'Heavy rain',
#    12: 'Heavy rain',
#    15: 'Light rain',
#    18: 'Moderate rain',
#    21: 'Light rain shower'},
#   'South',
#   '2019-04-01'],
#  [{0: 'Partly cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'MidWest',
#   '2019-04-01'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Partly cloudy',
#    18: 'Partly cloudy',
#    21: 'Cloudy'},
#   'West',
#   '2019-04-01'],
#  [{0: 'Cloudy',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Cloudy',
#    18: 'Partly cloudy',
#    21: 'Patchy light rain'},
#   'NorthEast',
#   '2019-04-02'],
#  [{0: 'Moderate or heavy rain with thunder',
#    3: 'Fog',
#    6: 'Moderate rain',
#    9: 'Patchy light rain',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'South',
#   '2019-04-02'],
#  [{0: 'Overcast',
#    3: 'Light drizzle',
#    6: 'Light sleet',
#    9: 'Partly cloudy',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'MidWest',
#   '2019-04-02'],
#  [{0: 'Partly cloudy',
#    3: 'Partly cloudy',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Patchy light rain',
#    18: 'Partly cloudy',
#    21: 'Patchy light rain'},
#   'West',
#   '2019-04-02'],
#  [{0: 'Cloudy',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-04-03'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Overcast'},
#   'South',
#   '2019-04-03'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Partly cloudy',
#    12: 'Cloudy',
#    15: 'Patchy light rain',
#    18: 'Overcast',
#    21: 'Moderate rain'},
#   'MidWest',
#   '2019-04-03'],
#  [{0: 'Overcast',
#    3: 'Patchy light drizzle',
#    6: 'Patchy light drizzle',
#    9: 'Patchy light rain',
#    12: 'Patchy light drizzle',
#    15: 'Partly cloudy',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2019-04-03'],
#  [{0: 'Light drizzle',
#    3: 'Patchy light drizzle',
#    6: 'Patchy light drizzle',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'NorthEast',
#   '2019-04-17'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Cloudy',
#    21: 'Clear'},
#   'South',
#   '2019-04-17'],
#  [{0: 'Light rain shower',
#    3: 'Light rain shower',
#    6: 'Overcast',
#    9: 'Light rain shower',
#    12: 'Thundery outbreaks possible',
#    15: 'Light rain shower',
#    18: 'Partly cloudy',
#    21: 'Partly cloudy'},
#   'MidWest',
#   '2019-04-17'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'West',
#   '2019-04-17'],
#  [{0: 'Cloudy',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Light drizzle',
#    12: 'Patchy light drizzle',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Clear'},
#   'NorthEast',
#   '2019-04-18'],
#  [{0: 'Overcast',
#    3: 'Clear',
#    6: 'Partly cloudy',
#    9: 'Partly cloudy',
#    12: 'Partly cloudy',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Patchy rain possible'},
#   'South',
#   '2019-04-18'],
#  [{0: 'Cloudy',
#    3: 'Overcast',
#    6: 'Overcast',
#    9: 'Sunny',
#    12: 'Partly cloudy',
#    15: 'Cloudy',
#    18: 'Patchy rain possible',
#    21: 'Partly cloudy'},
#   'MidWest',
#   '2019-04-18'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'West',
#   '2019-04-18'],
#  [{0: 'Clear',
#    3: 'Partly cloudy',
#    6: 'Overcast',
#    9: 'Overcast',
#    12: 'Overcast',
#    15: 'Patchy rain possible',
#    18: 'Light rain shower',
#    21: 'Light rain shower'},
#   'NorthEast',
#   '2019-04-19'],
#  [{0: 'Patchy rain possible',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Patchy rain possible',
#    12: 'Moderate or heavy rain shower',
#    15: 'Moderate rain at times',
#    18: 'Clear',
#    21: 'Clear'},
#   'South',
#   '2019-04-19'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Clear',
#    21: 'Clear'},
#   'MidWest',
#   '2019-04-19'],
#  [{0: 'Clear',
#    3: 'Clear',
#    6: 'Sunny',
#    9: 'Sunny',
#    12: 'Sunny',
#    15: 'Sunny',
#    18: 'Partly cloudy',
#    21: 'Overcast'},
#   'West',
#   '2019-04-19']]

# %%
report = []
for i in range(len(Final_weather_report)):
    temp = []
    Final_weather_report[i] = list(Final_weather_report[i])
    if Final_weather_report[i][1] == 'New York, United States of America':
        temp.append('NorthEast')
    elif Final_weather_report[i][1] == 'Jacksonville, United States of America':
        temp.append('South')
    elif Final_weather_report[i][1] == 'Des Moines, United States of America':
        temp.append('MidWest')
    elif Final_weather_report[i][1] == 'Salt Lake City, United States of America':
        temp.append('West')   
    temp.append(Final_weather_report[i][2])
    temp.append(Final_weather_report[i][0][12])
    temp = tuple(temp)
    report.append(temp)

#Final_weather_report
report
# Out:
# [('2018-12-01', 'Sunny'),
#  ('2018-12-01', 'Moderate rain'),
#  ('2018-12-01', 'Heavy rain'),
#  ('2018-12-01', 'Partly cloudy'),
#  ('2018-12-02', 'Moderate rain'),
#  ('2018-12-02', 'Thundery outbreaks possible'),
#  ('2018-12-02', 'Overcast'),
#  ('2018-12-02', 'Partly cloudy'),
#  ('2018-12-03', 'Sunny'),
#  ('2018-12-03', 'Light rain shower'),
#  ('2018-12-03', 'Moderate snow'),
#  ('2018-12-03', 'Partly cloudy'),
#  ('2018-12-17', 'Partly cloudy'),
#  ('2018-12-17', 'Partly cloudy'),
#  ('2018-12-17', 'Sunny'),
#  ('2018-12-17', 'Partly cloudy'),
#  ('2018-12-18', 'Sunny'),
#  ('2018-12-18', 'Sunny'),
#  ('2018-12-18', 'Sunny'),
#  ('2018-12-18', 'Sunny'),
#  ('2018-12-19', 'Partly cloudy'),
#  ('2018-12-19', 'Cloudy'),
#  ('2018-12-19', 'Sunny'),
#  ('2018-12-19', 'Sunny'),
#  ('2019-01-03', 'Sunny'),
#  ('2019-01-03', 'Sunny'),
#  ('2019-01-03', 'Sunny'),
#  ('2019-01-03', 'Sunny'),
#  ('2019-01-04', 'Cloudy'),
#  ('2019-01-04', 'Patchy light drizzle'),
#  ('2019-01-04', 'Sunny'),
#  ('2019-01-04', 'Sunny'),
#  ('2019-01-05', 'Light rain shower'),
#  ('2019-01-05', 'Sunny'),
#  ('2019-01-05', 'Sunny'),
#  ('2019-01-05', 'Cloudy'),
#  ('2019-01-16', 'Sunny'),
#  ('2019-01-16', 'Sunny'),
#  ('2019-01-16', 'Cloudy'),
#  ('2019-01-16', 'Overcast'),
#  ('2019-01-17', 'Cloudy'),
#  ('2019-01-17', 'Sunny'),
#  ('2019-01-17', 'Overcast'),
#  ('2019-01-17', 'Overcast'),
#  ('2019-01-18', 'Overcast'),
#  ('2019-01-18', 'Partly cloudy'),
#  ('2019-01-18', 'Light snow'),
#  ('2019-01-18', 'Partly cloudy'),
#  ('2019-02-01', 'Overcast'),
#  ('2019-02-01', 'Light drizzle'),
#  ('2019-02-01', 'Mist'),
#  ('2019-02-01', 'Sunny'),
#  ('2019-02-02', 'Partly cloudy'),
#  ('2019-02-02', 'Light rain shower'),
#  ('2019-02-02', 'Light drizzle'),
#  ('2019-02-02', 'Patchy light drizzle'),
#  ('2019-02-03', 'Sunny'),
#  ('2019-02-03', 'Light rain shower'),
#  ('2019-02-03', 'Overcast'),
#  ('2019-02-03', 'Partly cloudy'),
#  ('2019-02-16', 'Sunny'),
#  ('2019-02-16', 'Overcast'),
#  ('2019-02-16', 'Cloudy'),
#  ('2019-02-16', 'Partly cloudy'),
#  ('2019-02-17', 'Sunny'),
#  ('2019-02-17', 'Cloudy'),
#  ('2019-02-17', 'Overcast'),
#  ('2019-02-17', 'Cloudy'),
#  ('2019-02-18', 'Overcast'),
#  ('2019-02-18', 'Cloudy'),
#  ('2019-02-18', 'Cloudy'),
#  ('2019-02-18', 'Partly cloudy'),
#  ('2019-03-01', 'Moderate snow'),
#  ('2019-03-01', 'Light drizzle'),
#  ('2019-03-01', 'Cloudy'),
#  ('2019-03-01', 'Sunny'),
#  ('2019-03-02', 'Overcast'),
#  ('2019-03-02', 'Light rain shower'),
#  ('2019-03-02', 'Overcast'),
#  ('2019-03-02', 'Cloudy'),
#  ('2019-03-03', 'Partly cloudy'),
#  ('2019-03-03', 'Light rain shower'),
#  ('2019-03-03', 'Sunny'),
#  ('2019-03-03', 'Cloudy'),
#  ('2019-03-16', 'Partly cloudy'),
#  ('2019-03-16', 'Cloudy'),
#  ('2019-03-16', 'Partly cloudy'),
#  ('2019-03-16', 'Sunny'),
#  ('2019-03-17', 'Sunny'),
#  ('2019-03-17', 'Light rain'),
#  ('2019-03-17', 'Sunny'),
#  ('2019-03-17', 'Sunny'),
#  ('2019-03-18', 'Partly cloudy'),
#  ('2019-03-18', 'Sunny'),
#  ('2019-03-18', 'Cloudy'),
#  ('2019-03-18', 'Overcast'),
#  ('2019-04-01', 'Sunny'),
#  ('2019-04-01', 'Heavy rain'),
#  ('2019-04-01', 'Sunny'),
#  ('2019-04-01', 'Partly cloudy'),
#  ('2019-04-02', 'Sunny'),
#  ('2019-04-02', 'Sunny'),
#  ('2019-04-02', 'Sunny'),
#  ('2019-04-02', 'Cloudy'),
#  ('2019-04-03', 'Sunny'),
#  ('2019-04-03', 'Sunny'),
#  ('2019-04-03', 'Cloudy'),
#  ('2019-04-03', 'Patchy light drizzle'),
#  ('2019-04-17', 'Sunny'),
#  ('2019-04-17', 'Sunny'),
#  ('2019-04-17', 'Thundery outbreaks possible'),
#  ('2019-04-17', 'Sunny'),
#  ('2019-04-18', 'Patchy light drizzle'),
#  ('2019-04-18', 'Partly cloudy'),
#  ('2019-04-18', 'Partly cloudy'),
#  ('2019-04-18', 'Sunny'),
#  ('2019-04-19', 'Overcast'),
#  ('2019-04-19', 'Moderate or heavy rain shower'),
#  ('2019-04-19', 'Sunny'),
#  ('2019-04-19', 'Sunny')]

# %%
# When I get my report of date, region and weather I will use loc to find rows with matching regions/dates and put my weather value in a new column

# %%
df['Weather'] = ''
df
# Out:
#          fl_date mkt_unique_carrier branded_code_share op_unique_carrier  \
# 9     2018-12-01                 AA       AA_CODESHARE                YV
# 11    2018-12-01                 NK                 NK                NK
# 12    2018-12-01                 NK                 NK                NK
# 13    2018-12-01                 NK                 NK                NK
# 14    2018-12-01                 NK                 NK                NK
# ...          ...                ...                ...               ...
# 49995 2019-04-19                 UA       UA_CODESHARE                AX
# 49996 2019-04-19                 UA       UA_CODESHARE                AX
# 49997 2019-04-19                 UA       UA_CODESHARE                AX
# 49998 2019-04-19                 UA       UA_CODESHARE                AX
# 49999 2019-04-19                 UA       UA_CODESHARE                AX
#
#       tail_num op_carrier_fl_num origin_airport_id  origin_city_name  \
# 9       N908FJ              5948             14730    Louisville, KY
# 11      N602NK               395             14100  Philadelphia, PA
# 12      N602NK               396             12889     Las Vegas, NV
# 13      N507NK               403             10397       Atlanta, GA
# 14      N507NK               403             12892   Los Angeles, CA
# ...        ...               ...               ...               ...
# 49995   N11113              4744             11292        Denver, CO
# 49996   N21129              4743             11637         Fargo, ND
# 49997   N846HK              4742             12389     Williston, ND
# 49998   N11121              4741             12389     Williston, ND
# 49999   N41104              4740             13342     Milwaukee, WI
#
#       dest_airport_id         dest_city_name  ...  taxi_in_missing  \
# 9               11298  Dallas/Fort Worth, TX  ...                0
# 11              12889          Las Vegas, NV  ...                0
# 12              14100       Philadelphia, PA  ...                0
# 13              11697    Fort Lauderdale, FL  ...                0
# 14              10397            Atlanta, GA  ...                0
# ...               ...                    ...  ...              ...
# 49995           15016          St. Louis, MO  ...                0
# 49996           13930            Chicago, IL  ...                0
# 49997           11292             Denver, CO  ...                0
# 49998           11292             Denver, CO  ...                0
# 49999           13930            Chicago, IL  ...                0
#
#        arr_time_missing  wheels_off_missing  taxi_out_missing  \
# 9                     0                   0                 0
# 11                    0                   0                 0
# 12                    0                   0                 0
# 13                    0                   0                 0
# 14                    0                   0                 0
# ...                 ...                 ...               ...
# 49995                 0                   0                 0
# 49996                 0                   0                 0
# 49997                 0                   0                 0
# 49998                 0                   0                 0
# 49999                 0                   0                 0
#
#        dep_delay_missing  dep_time_missing               City  State  \
# 9                      0                 0  Dallas/Fort Worth     TX
# 11                     0                 0          Las Vegas     NV
# 12                     0                 0       Philadelphia     PA
# 13                     0                 0    Fort Lauderdale     FL
# 14                     0                 0            Atlanta     GA
# ...                  ...               ...                ...    ...
# 49995                  0                 0          St. Louis     MO
# 49996                  0                 0            Chicago     IL
# 49997                  0                 0             Denver     CO
# 49998                  0                 0             Denver     CO
# 49999                  0                 0            Chicago     IL
#
#           Region  Weather
# 9          South
# 11          West
# 12     NorthEast
# 13         South
# 14         South
# ...          ...      ...
# 49995    MidWest
# 49996    MidWest
# 49997       West
# 49998       West
# 49999    MidWest
#
# [491229 rows x 42 columns]

# %%
for i in report:
    df.loc[df[['fl_date', 'Region']].isin(report[i]), ['Weather']] = report[2]
